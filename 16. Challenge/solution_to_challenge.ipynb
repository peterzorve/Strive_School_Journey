# %% [markdown]
# ## Rotation matrix

# %% [markdown]
# Multiplying a vector by a matrix is equivalent to apply a linear transformation to that vector. One common example, is the rotation matrix: ![image](https://wikimedia.org/api/rest_v1/media/math/render/svg/678b1828be1c7064bc3f25cd1cb323f88f0d8acf)

# %% [markdown]
# where the theta is the angle by which the vector is rotated.
#
# Could you create a function that:
#
# - receive the angle as input argument and a vector as input
# - plots both the original and the transformed vector on the same plot but with different colors
#
# ?
#
# BONUS: https://matplotlib.org/stable/api/animation_api.html
#
# Can you make an animation that shows the intermediate steps of the rotation and save into a gif?
#
# Tip: don't contraint your imagination.

# %%
import numpy as np 
import matplotlib.pyplot as plt

def rotation(angle, vector):
    final_vector = None

    if type(vector) == int or type(vector) == float:
        print('Vector cannot be only one value: Enter two values in a square bracket')
 
    elif len(vector) == 2:
        angle = np.radians(angle)
        initial_vector = np.array(vector)
        rotation_matrix = np.array([ [round(np.cos(angle),4), round(-np.sin(angle),4)], [round(np.sin(angle),4), round(np.cos(angle),4)]])
        final_vector = np.dot(rotation_matrix, initial_vector)

        plt.plot(initial_vector[0], initial_vector[1], marker="o", markersize=10, markeredgecolor="green", markerfacecolor="green")
        plt.plot(final_vector[0], final_vector[1], marker="o", markersize=10, markeredgecolor="red", markerfacecolor="red")
        plt.axhline(y=0)
        plt.axvline(x=0)      

    else: 
        print('Vector should take only two values in a square bracket')
       

    return final_vector

rotation(45, [10, 0])
# Out:
# array([7.071, 7.071])

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/chriswmann/datasets/master/500_Person_Gender_Height_Weight_Index.csv")
df
# Out:
#      Gender  Height  Weight  Index
# 0      Male     174      96      4
# 1      Male     189      87      2
# 2    Female     185     110      4
# 3    Female     195     104      3
# 4      Male     149      61      3
# ..      ...     ...     ...    ...
# 495  Female     150     153      5
# 496  Female     184     121      4
# 497  Female     141     136      5
# 498    Male     150      95      5
# 499    Male     173     131      5
#
# [500 rows x 4 columns]

# %% [markdown]
# You have collected some data about 500 samples of people.
#
# You have information about the weight, the height, the gender and the BMI of the person.
#
# For the BMI:
#
# - 0 means 'Extremely Weak'
# - 1 means 'Weak'
# - 2 means 'Normal'
# - 3 means 'Overweight'
# - 4 means 'Obesity'
# - 5 means 'Extreme Obesity'

# %%
df.Index.value_counts()
# Out:
# 5    198
# 4    130
# 2     69
# 3     68
# 1     22
# 0     13
# Name: Index, dtype: int64

# %% [markdown]
# - Can you make an overview about them? For example: how many women are overweight? How many men? Etc etc.
#
# - Can you plot the data such that on the x axis you have the weight, on the y axis you have the height, and the individuals of the same BMI (column index) get colored with the same color?

# %%
df

# %%
#df.value_counts('Gender')

female_extremely_weak = df[df.Gender == 'Female'][df.Index == 0]
female_weak = df[df.Gender == 'Female'][df.Index == 1]
female_normal = df[df.Gender == 'Female'][df.Index == 2]
female_overweight = df[df.Gender == 'Female'][df.Index == 3]
female_obesity = df[df.Gender == 'Female'][df.Index == 4]
female_extremely_obesity = df[df.Gender == 'Female'][df.Index == 5]

male_extremely_weak = df[df.Gender == 'Male'][df.Index == 0]
male_weak = df[df.Gender == 'Male'][df.Index == 1]
male_normal = df[df.Gender == 'Male'][df.Index == 2]
male_overweight = df[df.Gender == 'Male'][df.Index == 3]
male_obesity = df[df.Gender == 'Male'][df.Index == 4]
male_extremely_obesity = df[df.Gender == 'Male'][df.Index == 5]

cases = ['Extremely Weak', 'Weak', 'Normal', 'Overweight', 'Obesity', 'Extremely Obesity']
cases_female = [len(female_extremely_weak), len(female_weak), len(female_normal), len(female_overweight), len(female_obesity), len(female_extremely_obesity)]
cases_female = [len(male_extremely_weak), len(male_weak), len(male_normal), len(male_overweight), len(male_obesity), len(male_extremely_obesity)]

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
cases = ['Extremely Weak', 'Weak', 'Normal', 'Overweight', 'Obesity', 'Extremely Obesity']
cases_female = [len(female_extremely_weak), len(female_weak), len(female_normal), len(female_overweight), len(female_obesity), len(female_extremely_obesity)]
cases_male = [len(male_extremely_weak), len(male_weak), len(male_normal), len(male_overweight), len(male_obesity), len(male_extremely_obesity)]

print(cases)
print(cases_female)
print(cases_male)
# Out:
# ['Extremely Weak', 'Weak', 'Normal', 'Overweight', 'Obesity', 'Extremely Obesity']
# [7, 7, 41, 36, 71, 93]
# [6, 15, 28, 32, 59, 105]

# %%
# plt.bar(cases, cases_female)
# plt.bar(cases, cases_male)

fig, ax = plt.subplots(figsize=(12,8))
width = 0.4
r = np.arange(len(cases))
plt.bar(r, cases_female, width = width, label = 'Female')
plt.bar(r+width, cases_male, width =width, label = 'Male')
#plt.bar(r+width + 0.2,df4['toothpaste'], width =width, label = 'toothpaste sales', rwidth = 0.5)
plt.xticks(r+0.2, cases)


plt.grid(True,linestyle = '--')
plt.legend()
plt.show()

# %% [markdown]
# - Can you make an overview about them? For example: how many women are overweight? How many men? Etc etc.
#
# - Can you plot the data such that on the x axis you have the weight, on the y axis you have the height, and the individuals of the same BMI (column index) get colored with the same color?

# %%
df
# Out:
#      Gender  Height  Weight  Index
# 0      Male     174      96      4
# 1      Male     189      87      2
# 2    Female     185     110      4
# 3    Female     195     104      3
# 4      Male     149      61      3
# ..      ...     ...     ...    ...
# 495  Female     150     153      5
# 496  Female     184     121      4
# 497  Female     141     136      5
# 498    Male     150      95      5
# 499    Male     173     131      5
#
# [500 rows x 4 columns]

# %%
# For Males 

male_height = df[df.Gender == 'Male'].Height
male_weight = df[df.Gender == 'Male'].Weight

plt.scatter(male_weight, male_height, c=male_weight.index)

# %%
# For Females 

female_height = df[df.Gender == 'Female'].Height
female_weight = df[df.Gender == 'Female'].Weight

plt.scatter(female_weight, female_height, c=female_weight.index)

# %% [markdown]
# Can you plot the histograms of the height of males, females and the total dataset?
#
# Do the same for the weight.

# %%
plt.hist(male_height)
# Out:
# (array([29., 18., 22., 26., 22., 21., 34., 28., 26., 19.]),
#  array([140. , 145.9, 151.8, 157.7, 163.6, 169.5, 175.4, 181.3, 187.2,
#         193.1, 199. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(male_weight)
# Out:
# (array([21., 22., 26., 21., 28., 28., 18., 21., 34., 26.]),
#  array([ 50.,  61.,  72.,  83.,  94., 105., 116., 127., 138., 149., 160.]),
#  <BarContainer object of 10 artists>)

# %%
# Males weight

# %%
# Females height

plt.hist(female_height)
# Out:
# (array([13., 27., 28., 21., 38., 21., 28., 41., 21., 17.]),
#  array([140. , 145.9, 151.8, 157.7, 163.6, 169.5, 175.4, 181.3, 187.2,
#         193.1, 199. ]),
#  <BarContainer object of 10 artists>)

# %%
# Females Weight

plt.hist(female_weight)
# Out:
# (array([28., 27., 18., 25., 27., 26., 26., 19., 27., 32.]),
#  array([ 50.,  61.,  72.,  83.,  94., 105., 116., 127., 138., 149., 160.]),
#  <BarContainer object of 10 artists>)

# %%
# Total Dataset Height

plt.hist(df.Height)
# Out:
# (array([42., 45., 50., 47., 60., 42., 62., 69., 47., 36.]),
#  array([140. , 145.9, 151.8, 157.7, 163.6, 169.5, 175.4, 181.3, 187.2,
#         193.1, 199. ]),
#  <BarContainer object of 10 artists>)

# %%
# Total Dataset Weight 

plt.hist(df.Weight)
# Out:
# (array([49., 49., 44., 46., 55., 54., 44., 40., 61., 58.]),
#  array([ 50.,  61.,  72.,  83.,  94., 105., 116., 127., 138., 149., 160.]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Euclidean Distance

# %%
mean_vector = [df.Weight.mean(), df.Height.mean()]
mean_vector
# Out:
# [106.0, 169.944]

# %% [markdown]
# - I know that is less efficient, but I want to see if you understand the concept of the mean of vectors: can you redo the process with a for loop?

# %% [markdown]
# - Plot the data again together with the mean value that must be visible in the middle, maybe with another size or marker and color

# %%
weight_all = df.Weight
weight = 0
for weight_a in weight_all:
    weight +=  weight_a
mean_weight = weight / len(weight_all)


height_all = df.Height
height = 0
for height_a in height_all:
    height +=  height_a
mean_height = height / len(height_all)

print([mean_weight, mean_height])
# Out:
# [106.0, 169.944]

# %%
plt.scatter(df['Weight'], df['Height'], c=df.Index )
plt.scatter(mean_weight, mean_height, marker='o', s=250, c='red')

# %% [markdown]
# It's not surprising that is perfectly in the middle, is it?
#
# Now, compute the mean of the elements that have a specific BMI: for example, the mean of all the elements with index 1, then the mean of the elements of index 2...
#
# Plot the mean of the all points as above together with the means of the different groups, all with different colors. Don't plot the rest of the points, they would lead to confusion.
#
# Don't forget to add the legend!

# %%
# Out:
# 60     Female
# 62       Male
# 79       Male
# 85       Male
# 99     Female
# 150    Female
# 214    Female
# 224      Male
# 244    Female
# 273    Female
# 354      Male
# 453      Male
# 492    Female
# Name: Gender, dtype: object

# %%
extremely_weak = df[df.Index == 0]['Index']
weak = df[df.Index == 1]['Index']
normal = df[df.Index == 2]['Index']
overweight = df[df.Index == 3]['Index']
obesity = df[df.Index == 4]['Index']
extremely_obesity = df[df.Index == 5]['Index']


extremely_weak_mean = extremely_weak.mean()
weak_mean = df[df.Index == 1].mean()
normal_mean = df[df.Index == 2].mean()
overweight_mean = df[df.Index == 3].mean()
obesity_mean = df[df.Index == 4].mean()
extremely_obesity_mean = df[df.Index == 5].mean()

print(extremely_weak)

# index_mean = [extremely_weak_mean, weak_mean, normal_mean, overweight_mean, obesity_mean, extremely_obesity_mean]

df

# %%
# Height and Weight

height_mean_extremely_weak            =   round(df[df.Index == 0]['Height'].mean(), 2)
height_mean_weak_mean                 =   round(df[df.Index == 1]['Height'].mean(), 2)
height_mean_normal_mean               =   round(df[df.Index == 2]['Height'].mean(), 2)
height_mean_overweight_mean           =   round(df[df.Index == 3]['Height'].mean(), 2)
height_mean_obesity_mean              =   round(df[df.Index == 4]['Height'].mean(), 2)
height_mean_extremely_obesity_mean    =   round(df[df.Index == 5]['Height'].mean(), 2)

weight_mean_extremely_weak            =   round(df[df.Index == 0]['Weight'].mean(), 2)
weight_mean_weak_mean                 =   round(df[df.Index == 1]['Weight'].mean(), 2)
weight_mean_normal_mean               =   round(df[df.Index == 2]['Weight'].mean(), 2)
weight_mean_overweight_mean           =   round(df[df.Index == 3]['Weight'].mean(), 2)
weight_mean_obesity_mean              =   round(df[df.Index == 4]['Weight'].mean(), 2)
weight_mean_extremely_obesity_mean    =   round(df[df.Index == 5]['Weight'].mean(), 2)

# height_index_mean = [height_mean_extremely_weak, height_mean_weak_mean, height_mean_normal_mean, height_mean_overweight_mean, height_mean_obesity_mean, height_mean_extremely_obesity_mean]
# weight_index_mean = [weight_mean_extremely_weak, weight_mean_weak_mean, weight_mean_normal_mean, weight_mean_overweight_mean, weight_mean_obesity_mean, weight_mean_extremely_obesity_mean]

height_index_mean_0 = [height_mean_extremely_weak]
weight_index_mean_0 = [weight_mean_extremely_weak]

height_index_mean_1 = [height_mean_weak_mean]
weight_index_mean_1 = [weight_mean_weak_mean]

height_index_mean_2 = [height_mean_normal_mean]
weight_index_mean_2 = [weight_mean_normal_mean]

height_index_mean_3 = [height_mean_overweight_mean]
weight_index_mean_3 = [weight_mean_overweight_mean]

height_index_mean_4 = [height_mean_obesity_mean]
weight_index_mean_4 = [weight_mean_obesity_mean]

height_index_mean_5 = [height_mean_extremely_obesity_mean]
weight_index_mean_5 = [ weight_mean_extremely_obesity_mean]


height_index_mean = [height_mean_extremely_weak, height_mean_weak_mean, height_mean_normal_mean, height_mean_overweight_mean, height_mean_obesity_mean, height_mean_extremely_obesity_mean]
weight_index_mean = [weight_mean_extremely_weak, weight_mean_weak_mean, weight_mean_normal_mean, weight_mean_overweight_mean, weight_mean_obesity_mean, weight_mean_extremely_obesity_mean]

height_mean_array = np.array([height_index_mean]).mean()
weight_mean_array = np.array([weight_index_mean]).mean()

fig, ax = plt.subplots(figsize=(10, 8))
plt.plot(weight_index_mean_0, height_index_mean_0, marker='o', markersize=15, label='extremely_weak')
plt.plot(weight_index_mean_1, height_index_mean_1, marker='o', markersize=15, label='weak')
plt.plot(weight_index_mean_2, height_index_mean_2, marker='o', markersize=15, label='normal')
plt.plot(weight_index_mean_3, height_index_mean_3, marker='o', markersize=15, label='overweight')
plt.plot(weight_index_mean_4, height_index_mean_4, marker='o', markersize=15, label='obesity')
plt.plot(weight_index_mean_5, height_index_mean_5, marker='o', markersize=15, label='extremely_obesity')

plt.plot(weight_mean_array, height_mean_array, marker='o', markersize=15, label='mean')

plt.legend()



# plt.scatter(weight_index_mean, height_index_mean) #, marker='o', s=250, c='red')
# plt.legend(si)

# %%
# Out:
# C:\Users\Omistaja\AppData\Local\Temp\ipykernel_19612\2429060366.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   extremely_weak_mean = df[df.Index == 0].mean()
# C:\Users\Omistaja\AppData\Local\Temp\ipykernel_19612\2429060366.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   weak_mean = df[df.Index == 1].mean()
# C:\Users\Omistaja\AppData\Local\Temp\ipykernel_19612\2429060366.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   normal_mean = df[df.Index == 2].mean()
# ...
